# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense,Conv1D, MaxPool1D
from tensorflow.keras.layers import Dropout, Input, BatchNormalization
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.losses import categorical_crossentropy, binary_crossentropy
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd
from PIL import Image

# %%
game = pd.read_csv('game.csv')

# %%
game_num = game.to_numpy()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17064/3250655244.py in <module>
# ----> 1 np.isnan('nan')
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
for i in  range(len(game_num)):
    for j in range(45):
        if(isinstance(game_num[i][j],str) or isinstance(game_num[i][j],int) or isinstance(game_num[i][j],float)):
            continue
        else:
            print(i)

# %%
def get_players(i):
    players=[];
    for j in range(0, 30):
        players.append(game_num[i][5+j])
    date = game_num[i][1]
    return (players, date)

# %%
def change_player_data(player):
    player_name=player
    path = 'players/' + player +'.csv'
    player = pd.read_csv(path)
    player_data = np.array(player)
    
    temp=np.zeros(player_data.shape[0])
    temp=temp.reshape(player_data.shape[0],1)
#     player_data=np.append(player_data,temp, axis=1)

    for i in range(0, len(player_data)):
        player_data[i][1]=player_data[i][1].replace('/','-')
#         print(player_data[i][1])
#         if player_data[i][5]=="Inactive" or player_data[i][5]=="Did Not Dress" or player_data[i][5]=="Did Not Play" or player_data[i][5]=="Not With Team" or player_data[i][5]=="Player Suspended":
#             player_data[i][5:]=0
#             player_data[i][24]=1
    player_data_df = pd.DataFrame(player_data)
    player_data_df.to_csv("D:/class_note/grade_3_fitst_semester/ML/final_project/player1/"+ player_name+ ".csv",index = False)

# %%
total_num_of_game  = game_num.shape[0]
total_num_of_player_in_one_game = 30
for i in range(0, total_num_of_game):
    if(i%100==0):
        print(i)
    players=[]
    (players, date) = get_players(i)
#     print(i)
    for j in range(0, len(players)):
        if(players[j]=='none'):
            continue
        else:
            print(players[j])
            change_player_data(players[j]);
# Out:
# 0
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Goran Dragic
# Hassan Whiteside
# Jalen Johnson
# James Johnson
# Josh Richardson
# Justise Winslow
# Rodney McGruder
# Udonis Haslem
# Wayne Ellington
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Andre Drummond
# Boban Marjanovic
# Ish Smith
# Kentavious Caldwell-Pope
# Marcus Morris
# Reggie Bullock
# Reggie Jackson
# Tobias Harris
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Kevin Love
# Kyrie Irving
# LeBron James
# Tristan Thompson
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Serge Ibaka
# Giannis Antetokounmpo
# Greg Monroe
# Jabari Parker
# Khris Middleton
# Malcolm Brogdon
# Tony Snell
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Alex Len
# Brandon Knight
# Derrick Jones Jr
# Devin Booker
# Eric Bledsoe
# Marquese Chriss
# P.J. Tucker
# T.J. Warren
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Bradley Beal
# John Wall
# Kelly Oubre Jr
# Markieff Morris
# Otto Porter Jr
# Tomas Satoransky
# Trey Burke
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Giannis Antetokounmpo
# Greg Monroe
# Jabari Parker
# Khris Middleton
# Malcolm Brogdon
# Tony Snell
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Bryn Forbes
# Danny Green
# Davis Bertans
# Dejounte Murray
# Dewayne Dedmon
# Kawhi Leonard
# Kyle Anderson
# LaMarcus Aldridge
# Patty Mills
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# James Ennis III
# JaMychal Green
# Mike Conley
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Ben Simmons
# Dario Saric
# Joel Embiid
# Nerlens Noel
# Nik Statuskas
# Richaun Holmes
# Robert Covington
# T.J. McConnell
# Timothe Luwawu-Cabarrot
# Aaron Gordon
# Bismack Biyombo
# D.J. Augustin
# Elfrid Payton
# Evan Fournier
# Jeff Green
# Nikola Vucevic
# Serge Ibaka
# Andre Drummond
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17064/2385849847.py in <module>
#      11             continue
#      12         else:
# ---> 13             print(players[j])
#      14             change_player_data(players[j]);
#
# c:\users\dan89\appdata\local\programs\python\python39\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     517             is_child = (not self._is_master_process())
#     518             # only touch the buffer in the IO thread to avoid races
# --> 519             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     520             if is_child:
#     521                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# c:\users\dan89\appdata\local\programs\python\python39\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# c:\users\dan89\appdata\local\programs\python\python39\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\users\dan89\appdata\local\programs\python\python39\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
print(players[779])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7412/1028206276.py in <module>
# ----> 1 print(players[779])
#
# IndexError: list index out of range
